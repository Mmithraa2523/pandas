# %%
import pandas as pd
df = pd.read_csv("silver\hcltech.csv")

# %%
print(df.head())
df.info()
# Out:
#          Date  Adj Close  Close  High   Low  Open   Volume
# 0  2025-06-23       1633   1703  1730  1699  1729  2221446
# 1  2025-06-24       1622   1692  1733  1689  1720  3601071
# 2  2025-06-25       1647   1717  1721  1701  1702  1307518
# 3  2025-06-26       1653   1724  1727  1703  1710  2971055
# 4  2025-06-27       1653   1723  1752  1711  1735  6478283
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       247 non-null    object
#  1   Adj Close  247 non-null    int64
#  2   Close      247 non-null    int64
#  3   High       247 non-null    int64
#  4   Low        247 non-null    int64
#  5   Open       247 non-null    int64
#  6   Volume     247 non-null    int64
# dtypes: int64(6), object(1)
# memory usage: 13.6+ KB
